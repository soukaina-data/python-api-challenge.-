# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests as rq
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
import sys

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

city_data=[]  
recor_count = 1
set_count= 1

print("Begining Data Retrieval")
print ("----------------")

for i, city in enumerate(cities):
    if (i%50==0 and i>=50):
        set_count+=1
        recor_count=0
    print(f"Processing record {recor_count} of set {set_count} | {city}")
    recor_count+=1
    city_url=url+"&q="+city
    #print(city_url)
    
    try:
        city_weather=rq.get(city_url).json()
        city_data.append({ 
            "City": city,
            "Lat": city_weather["coord"]["lat"],
            "Lon": city_weather["coord"]["lon"],
            "Max Temp": city_weather["main"]["temp_max"],
            "Humidity": city_weather["main"]["humidity"],
            "High Winds": city_weather["wind"]["speed"],
            "Country": city_weather["sys"]["country"],
            "Date": city_weather["dt"],
            #"Cloudiness": city_weather["cloudiness"]

        })
        print(f"City {city} found and added")
    except:
        sys.exc_info()[0]
        print(f"City {city} not found.  Skipping...")
        pass
                 
print("===============")
print("data retrieval completed")
print ("===============")
# Out:
# Begining Data Retrieval
# ----------------
# Processing record 1 of set 1 | pevek
# City pevek found and added
# Processing record 2 of set 1 | chumikan
# City chumikan found and added
# Processing record 3 of set 1 | mezen
# City mezen found and added
# Processing record 4 of set 1 | puerto ayora
# City puerto ayora found and added
# Processing record 5 of set 1 | rikitea
# City rikitea found and added
# Processing record 6 of set 1 | avera
# City avera found and added
# Processing record 7 of set 1 | airai
# City airai found and added
# Processing record 8 of set 1 | kavaratti
# City kavaratti found and added
# Processing record 9 of set 1 | chuy
# City chuy found and added
# Processing record 10 of set 1 | alice springs
# City alice springs found and added
# Processing record 11 of set 1 | kemin
# City kemin found and added
# Processing record 12 of set 1 | ribeira grande
# City ribeira grande found and added
# Processing record 13 of set 1 | ushuaia
# City ushuaia found and added
# Processing record 14 of set 1 | mataura
# City mataura found and added
# Processing record 15 of set 1 | duz
# City duz not found.  Skipping...
# Processing record 16 of set 1 | butaritari
# City butaritari found and added
# Processing record 17 of set 1 | cape town
# City cape town found and added
# Processing record 18 of set 1 | atuona
# City atuona found and added
# Processing record 19 of set 1 | kapaa
# City kapaa found and added
# Processing record 20 of set 1 | halifax
# City halifax found and added
# Processing record 21 of set 1 | tilichiki
# City tilichiki found and added
# Processing record 22 of set 1 | bismarck
# City bismarck found and added
# Processing record 23 of set 1 | puerto baquerizo moreno
# City puerto baquerizo moreno found and added
# Processing record 24 of set 1 | aklavik
# City aklavik found and added
# Processing record 25 of set 1 | new norfolk
# City new norfolk found and added
# Processing record 26 of set 1 | georgetown
# City georgetown found and added
# Processing record 27 of set 1 | luderitz
# City luderitz found and added
# Processing record 28 of set 1 | ilulissat
# City ilulissat found and added
# Processing record 29 of set 1 | hilo
# City hilo found and added
# Processing record 30 of set 1 | punta arenas
# City punta arenas found and added
# Processing record 31 of set 1 | faanui
# City faanui found and added
# Processing record 32 of set 1 | sarlat-la-caneda
# City sarlat-la-caneda found and added
# Processing record 33 of set 1 | ahuimanu
# City ahuimanu found and added
# Processing record 34 of set 1 | belushya guba
# City belushya guba not found.  Skipping...
# Processing record 35 of set 1 | taolanaro
# City taolanaro not found.  Skipping...
# Processing record 36 of set 1 | san juan
# City san juan found and added
# Processing record 37 of set 1 | acapulco
# City acapulco found and added
# Processing record 38 of set 1 | bairiki
# City bairiki not found.  Skipping...
# Processing record 39 of set 1 | tezu
# City tezu found and added
# Processing record 40 of set 1 | vaini
# City vaini found and added
# Processing record 41 of set 1 | kloulklubed
# City kloulklubed found and added
# Processing record 42 of set 1 | saint-philippe
# City saint-philippe found and added
# Processing record 43 of set 1 | ayagoz
# City ayagoz found and added
# Processing record 44 of set 1 | port alfred
# City port alfred found and added
# Processing record 45 of set 1 | samusu
# City samusu not found.  Skipping...
# Processing record 46 of set 1 | aswan
# City aswan found and added
# Processing record 47 of set 1 | fortuna
# City fortuna found and added
# Processing record 48 of set 1 | tuatapere
# City tuatapere found and added
# Processing record 49 of set 1 | jamestown
# City jamestown found and added
# Processing record 50 of set 1 | seoul
# City seoul found and added
# Processing record 0 of set 2 | bethel
# City bethel found and added
# Processing record 1 of set 2 | sataua
# City sataua not found.  Skipping...
# Processing record 2 of set 2 | mar del plata
# City mar del plata found and added
# Processing record 3 of set 2 | nizhneyansk
# City nizhneyansk not found.  Skipping...
# Processing record 4 of set 2 | empalme
# City empalme found and added
# Processing record 5 of set 2 | albany
# City albany found and added
# Processing record 6 of set 2 | buraydah
# City buraydah found and added
# Processing record 7 of set 2 | taburi
# City taburi not found.  Skipping...
# Processing record 8 of set 2 | busselton
# City busselton found and added
# Processing record 9 of set 2 | alofi
# City alofi found and added
# Processing record 10 of set 2 | avarua
# City avarua found and added
# Processing record 11 of set 2 | illoqqortoormiut
# City illoqqortoormiut not found.  Skipping...
# Processing record 12 of set 2 | coquimbo
# City coquimbo found and added
# Processing record 13 of set 2 | tecoanapa
# City tecoanapa found and added
# Processing record 14 of set 2 | shirokiy
# City shirokiy found and added
# Processing record 15 of set 2 | hobart
# City hobart found and added
# Processing record 16 of set 2 | klaksvik
# City klaksvik found and added
# Processing record 17 of set 2 | sagara
# City sagara found and added
# Processing record 18 of set 2 | carnarvon
# City carnarvon found and added
# Processing record 19 of set 2 | rawson
# City rawson found and added
# Processing record 20 of set 2 | karlshamn
# City karlshamn found and added
# Processing record 21 of set 2 | bluff
# City bluff found and added
# Processing record 22 of set 2 | marawi
# City marawi found and added
# Processing record 23 of set 2 | xining
# City xining found and added
# Processing record 24 of set 2 | westport
# City westport found and added
# Processing record 25 of set 2 | east london
# City east london found and added
# Processing record 26 of set 2 | belaya gora
# City belaya gora found and added
# Processing record 27 of set 2 | louisbourg
# City louisbourg not found.  Skipping...
# Processing record 28 of set 2 | san andres
# City san andres found and added
# Processing record 29 of set 2 | round lake beach
# City round lake beach found and added
# Processing record 30 of set 2 | mzimba
# City mzimba found and added
# Processing record 31 of set 2 | iqaluit
# City iqaluit found and added
# Processing record 32 of set 2 | mentok
# City mentok not found.  Skipping...
# Processing record 33 of set 2 | vicuna
# City vicuna not found.  Skipping...
# Processing record 34 of set 2 | boguchany
# City boguchany found and added
# Processing record 35 of set 2 | neuquen
# City neuquen found and added
# Processing record 36 of set 2 | lasa
# City lasa found and added
# Processing record 37 of set 2 | hay river
# City hay river found and added
# Processing record 38 of set 2 | shingu
# City shingu found and added
# Processing record 39 of set 2 | constitucion
# City constitucion found and added
# Processing record 40 of set 2 | tabiauea
# City tabiauea not found.  Skipping...
# Processing record 41 of set 2 | metehara
# City metehara not found.  Skipping...
# Processing record 42 of set 2 | coihaique
# City coihaique found and added
# Processing record 43 of set 2 | taoudenni
# City taoudenni found and added
# Processing record 44 of set 2 | upernavik
# City upernavik found and added
# Processing record 45 of set 2 | zhongshu
# City zhongshu found and added
# Processing record 46 of set 2 | arraial do cabo
# City arraial do cabo found and added
# Processing record 47 of set 2 | linxia
# City linxia found and added
# Processing record 48 of set 2 | codrington
# City codrington found and added
# Processing record 49 of set 2 | mys shmidta
# City mys shmidta not found.  Skipping...
# Processing record 0 of set 3 | keti bandar
# City keti bandar found and added
# Processing record 1 of set 3 | brokopondo
# City brokopondo found and added
# Processing record 2 of set 3 | hermanus
# City hermanus found and added
# Processing record 3 of set 3 | poum
# City poum found and added
# Processing record 4 of set 3 | itoman
# City itoman found and added
# Processing record 5 of set 3 | thompson
# City thompson found and added
# Processing record 6 of set 3 | ahipara
# City ahipara found and added
# Processing record 7 of set 3 | broken hill
# City broken hill found and added
# Processing record 8 of set 3 | bolungarvik
# City bolungarvik not found.  Skipping...
# Processing record 9 of set 3 | tasiilaq
# City tasiilaq found and added
# Processing record 10 of set 3 | mahebourg
# City mahebourg found and added
# Processing record 11 of set 3 | bambous virieux
# City bambous virieux found and added
# Processing record 12 of set 3 | emerald
# City emerald found and added
# Processing record 13 of set 3 | agirish
# City agirish found and added
# Processing record 14 of set 3 | dali
# City dali found and added
# Processing record 15 of set 3 | wukari
# City wukari found and added
# Processing record 16 of set 3 | sungairaya
# City sungairaya found and added
# Processing record 17 of set 3 | port elizabeth
# City port elizabeth found and added
# Processing record 18 of set 3 | ingham
# City ingham found and added
# Processing record 19 of set 3 | lebu
# City lebu found and added
# Processing record 20 of set 3 | pangody
# City pangody found and added
# Processing record 21 of set 3 | petropavl
# City petropavl found and added
# Processing record 22 of set 3 | toliary
# City toliary not found.  Skipping...
# Processing record 23 of set 3 | keetmanshoop
# City keetmanshoop found and added
# Processing record 24 of set 3 | vilyuysk
# City vilyuysk found and added
# Processing record 25 of set 3 | nikolskoye
# City nikolskoye found and added
# Processing record 26 of set 3 | atasu
# City atasu found and added
# Processing record 27 of set 3 | ambon
# City ambon found and added
# Processing record 28 of set 3 | antofagasta
# City antofagasta found and added
# Processing record 29 of set 3 | srednekolymsk
# City srednekolymsk found and added
# Processing record 30 of set 3 | tsihombe
# City tsihombe not found.  Skipping...
# Processing record 31 of set 3 | tiksi
# City tiksi found and added
# Processing record 32 of set 3 | waipawa
# City waipawa found and added
# Processing record 33 of set 3 | sitka
# City sitka found and added
# Processing record 34 of set 3 | kaitangata
# City kaitangata found and added
# Processing record 35 of set 3 | hede
# City hede found and added
# Processing record 36 of set 3 | kinkala
# City kinkala found and added
# Processing record 37 of set 3 | olafsvik
# City olafsvik not found.  Skipping...
# Processing record 38 of set 3 | pemberton
# City pemberton found and added
# Processing record 39 of set 3 | barbar
# City barbar not found.  Skipping...
# Processing record 40 of set 3 | henties bay
# City henties bay found and added
# Processing record 41 of set 3 | nuuk
# City nuuk found and added
# Processing record 42 of set 3 | beloha
# City beloha found and added
# Processing record 43 of set 3 | umm lajj
# City umm lajj found and added
# Processing record 44 of set 3 | nouadhibou
# City nouadhibou found and added
# Processing record 45 of set 3 | haines junction
# City haines junction found and added
# Processing record 46 of set 3 | kodiak
# City kodiak found and added
# Processing record 47 of set 3 | bantry
# City bantry not found.  Skipping...
# Processing record 48 of set 3 | pisco
# City pisco found and added
# Processing record 49 of set 3 | ponta do sol
# City ponta do sol found and added
# Processing record 0 of set 4 | bantou
# City bantou found and added
# Processing record 1 of set 4 | somerset east
# City somerset east found and added
# Processing record 2 of set 4 | hithadhoo
# City hithadhoo found and added
# Processing record 3 of set 4 | ouargaye
# City ouargaye found and added
# Processing record 4 of set 4 | pangnirtung
# City pangnirtung found and added
# Processing record 5 of set 4 | sangar
# City sangar found and added
# Processing record 6 of set 4 | galiwinku
# City galiwinku not found.  Skipping...
# Processing record 7 of set 4 | tarko-sale
# City tarko-sale found and added
# Processing record 8 of set 4 | rocha
# City rocha found and added
# Processing record 9 of set 4 | sucua
# City sucua found and added
# Processing record 10 of set 4 | college
# City college found and added
# Processing record 11 of set 4 | vao
# City vao found and added
# Processing record 12 of set 4 | hamilton
# City hamilton found and added
# Processing record 13 of set 4 | superior
# City superior found and added
# Processing record 14 of set 4 | tobermory
# City tobermory found and added
# Processing record 15 of set 4 | saldanha
# City saldanha found and added
# Processing record 16 of set 4 | chapais
# City chapais found and added
# Processing record 17 of set 4 | attawapiskat
# City attawapiskat not found.  Skipping...
# Processing record 18 of set 4 | okhotsk
# City okhotsk found and added
# Processing record 19 of set 4 | haibowan
# City haibowan not found.  Skipping...
# Processing record 20 of set 4 | takoradi
# City takoradi found and added
# Processing record 21 of set 4 | tromso
# City tromso found and added
# Processing record 22 of set 4 | bilibino
# City bilibino found and added
# Processing record 23 of set 4 | kharp
# City kharp found and added
# Processing record 24 of set 4 | lompoc
# City lompoc found and added
# Processing record 25 of set 4 | mount isa
# City mount isa found and added
# Processing record 26 of set 4 | gushikawa
# City gushikawa found and added
# Processing record 27 of set 4 | svetlaya
# City svetlaya found and added
# Processing record 28 of set 4 | sentyabrskiy
# City sentyabrskiy not found.  Skipping...
# Processing record 29 of set 4 | conde
# City conde found and added
# Processing record 30 of set 4 | maceio
# City maceio found and added
# Processing record 31 of set 4 | bredasdorp
# City bredasdorp found and added
# Processing record 32 of set 4 | khatanga
# City khatanga found and added
# Processing record 33 of set 4 | yulara
# City yulara found and added
# Processing record 34 of set 4 | bandarbeyla
# City bandarbeyla found and added
# Processing record 35 of set 4 | zainsk
# City zainsk found and added
# Processing record 36 of set 4 | westerlo
# City westerlo found and added
# Processing record 37 of set 4 | sakakah
# City sakakah not found.  Skipping...
# Processing record 38 of set 4 | batagay-alyta
# City batagay-alyta found and added
# Processing record 39 of set 4 | torbay
# City torbay found and added
# Processing record 40 of set 4 | tautira
# City tautira found and added
# Processing record 41 of set 4 | laguna
# City laguna found and added
# Processing record 42 of set 4 | prince rupert
# City prince rupert found and added
# Processing record 43 of set 4 | kawalu
# City kawalu found and added
# Processing record 44 of set 4 | sao felix do xingu
# City sao felix do xingu found and added
# Processing record 45 of set 4 | mizan teferi
# City mizan teferi found and added
# Processing record 46 of set 4 | coahuayana
# City coahuayana found and added
# Processing record 47 of set 4 | nantucket
# City nantucket found and added
# Processing record 48 of set 4 | elizabeth city
# City elizabeth city found and added
# Processing record 49 of set 4 | sars
# City sars found and added
# Processing record 0 of set 5 | cherskiy
# City cherskiy found and added
# Processing record 1 of set 5 | cabo san lucas
# City cabo san lucas found and added
# Processing record 2 of set 5 | arlit
# City arlit found and added
# Processing record 3 of set 5 | makokou
# City makokou found and added
# Processing record 4 of set 5 | hun
# City hun found and added
# Processing record 5 of set 5 | anadyr
# City anadyr found and added
# Processing record 6 of set 5 | husavik
# City husavik found and added
# Processing record 7 of set 5 | qaanaaq
# City qaanaaq found and added
# Processing record 8 of set 5 | ust-kan
# City ust-kan found and added
# Processing record 9 of set 5 | hatillo
# City hatillo found and added
# Processing record 10 of set 5 | ouallam
# City ouallam found and added
# Processing record 11 of set 5 | touros
# City touros found and added
# Processing record 12 of set 5 | parana
# City parana found and added
# Processing record 13 of set 5 | bengkulu
# City bengkulu not found.  Skipping...
# Processing record 14 of set 5 | crossville
# City crossville found and added
# Processing record 15 of set 5 | jega
# City jega found and added
# Processing record 16 of set 5 | amderma
# City amderma not found.  Skipping...
# Processing record 17 of set 5 | aitape
# City aitape found and added
# Processing record 18 of set 5 | san ramon
# City san ramon found and added
# Processing record 19 of set 5 | cochrane
# City cochrane found and added
# Processing record 20 of set 5 | tommot
# City tommot found and added
# Processing record 21 of set 5 | jiangyou
# City jiangyou found and added
# Processing record 22 of set 5 | umea
# City umea found and added
# Processing record 23 of set 5 | bulgan
# City bulgan found and added
# Processing record 24 of set 5 | de-kastri
# City de-kastri found and added
# Processing record 25 of set 5 | grand gaube
# City grand gaube found and added
# Processing record 26 of set 5 | abilene
# City abilene found and added
# Processing record 27 of set 5 | jacareacanga
# City jacareacanga found and added
# Processing record 28 of set 5 | humberto de campos
# City humberto de campos found and added
# Processing record 29 of set 5 | provideniya
# City provideniya found and added
# Processing record 30 of set 5 | victoria
# City victoria found and added
# Processing record 31 of set 5 | krasnoborsk
# City krasnoborsk found and added
# Processing record 32 of set 5 | calbuco
# City calbuco found and added
# Processing record 33 of set 5 | vostok
# City vostok found and added
# Processing record 34 of set 5 | saint george
# City saint george found and added
# Processing record 35 of set 5 | amposta
# City amposta found and added
# Processing record 36 of set 5 | ambilobe
# City ambilobe found and added
# Processing record 37 of set 5 | hope
# City hope found and added
# Processing record 38 of set 5 | havelock
# City havelock found and added
# Processing record 39 of set 5 | semnan
# City semnan found and added
# Processing record 40 of set 5 | esperance
# City esperance found and added
# Processing record 41 of set 5 | lahij
# City lahij found and added
# Processing record 42 of set 5 | palabuhanratu
# City palabuhanratu not found.  Skipping...
# Processing record 43 of set 5 | cidreira
# City cidreira found and added
# Processing record 44 of set 5 | port moresby
# City port moresby found and added
# Processing record 45 of set 5 | leningradskiy
# City leningradskiy found and added
# Processing record 46 of set 5 | namwala
# City namwala found and added
# Processing record 47 of set 5 | port blair
# City port blair found and added
# Processing record 48 of set 5 | tual
# City tual found and added
# Processing record 49 of set 5 | sao filipe
# City sao filipe found and added
# Processing record 0 of set 6 | namibe
# City namibe found and added
# Processing record 1 of set 6 | umzimvubu
# City umzimvubu not found.  Skipping...
# Processing record 2 of set 6 | yellowknife
# City yellowknife found and added
# Processing record 3 of set 6 | oranjemund
# City oranjemund found and added
# Processing record 4 of set 6 | san jose
# City san jose found and added
# Processing record 5 of set 6 | meulaboh
# City meulaboh found and added
# Processing record 6 of set 6 | carutapera
# City carutapera found and added
# Processing record 7 of set 6 | mount gambier
# City mount gambier found and added
# Processing record 8 of set 6 | chokurdakh
# City chokurdakh found and added
# Processing record 9 of set 6 | zhigansk
# City zhigansk found and added
# Processing record 10 of set 6 | kavieng
# City kavieng found and added
# Processing record 11 of set 6 | cap malheureux
# City cap malheureux found and added
# Processing record 12 of set 6 | port lincoln
# City port lincoln found and added
# Processing record 13 of set 6 | severo-kurilsk
# City severo-kurilsk found and added
# Processing record 14 of set 6 | atbasar
# City atbasar found and added
# Processing record 15 of set 6 | fare
# City fare found and added
# Processing record 16 of set 6 | dikson
# City dikson found and added
# Processing record 17 of set 6 | castro
# City castro found and added
# Processing record 18 of set 6 | blankenberge
# City blankenberge found and added
# Processing record 19 of set 6 | longyearbyen
# City longyearbyen found and added
# Processing record 20 of set 6 | tazovskiy
# City tazovskiy found and added
# Processing record 21 of set 6 | omsukchan
# City omsukchan found and added
# Processing record 22 of set 6 | faya
# City faya found and added
# Processing record 23 of set 6 | annamalainagar
# City annamalainagar found and added
# Processing record 24 of set 6 | uige
# City uige found and added
# Processing record 25 of set 6 | farrukhabad
# City farrukhabad found and added
# Processing record 26 of set 6 | bud
# City bud found and added
# Processing record 27 of set 6 | valparaiso
# City valparaiso found and added
# Processing record 28 of set 6 | claremont
# City claremont found and added
# Processing record 29 of set 6 | tuktoyaktuk
# City tuktoyaktuk found and added
# Processing record 30 of set 6 | kemijarvi
# City kemijarvi not found.  Skipping...
# Processing record 31 of set 6 | lata
# City lata found and added
# Processing record 32 of set 6 | klyuchi
# City klyuchi found and added
# Processing record 33 of set 6 | kirkwood
# City kirkwood found and added
# Processing record 34 of set 6 | senneterre
# City senneterre found and added
# Processing record 35 of set 6 | ostrovnoy
# City ostrovnoy found and added
# Processing record 36 of set 6 | cabra
# City cabra found and added
# Processing record 37 of set 6 | galesong
# City galesong found and added
# Processing record 38 of set 6 | barrow
# City barrow found and added
# Processing record 39 of set 6 | san quintin
# City san quintin found and added
# Processing record 40 of set 6 | riyaq
# City riyaq not found.  Skipping...
# Processing record 41 of set 6 | talcahuano
# City talcahuano found and added
# Processing record 42 of set 6 | hofu
# City hofu found and added
# Processing record 43 of set 6 | vilnius
# City vilnius found and added
# Processing record 44 of set 6 | grand river south east
# City grand river south east not found.  Skipping...
# Processing record 45 of set 6 | erzin
# City erzin found and added
# Processing record 46 of set 6 | kempsey
# City kempsey found and added
# Processing record 47 of set 6 | moron
# City moron found and added
# Processing record 48 of set 6 | port keats
# City port keats found and added
# Processing record 49 of set 6 | petropavlovsk-kamchatskiy
# City petropavlovsk-kamchatskiy found and added
# Processing record 0 of set 7 | santa isabel do rio negro
# City santa isabel do rio negro found and added
# Processing record 1 of set 7 | hargeysa
# City hargeysa found and added
# Processing record 2 of set 7 | kampong chhnang
# City kampong chhnang found and added
# Processing record 3 of set 7 | saint-louis
# City saint-louis found and added
# Processing record 4 of set 7 | vaitupu
# City vaitupu not found.  Skipping...
# Processing record 5 of set 7 | san jeronimo
# City san jeronimo found and added
# Processing record 6 of set 7 | yeniseysk
# City yeniseysk found and added
# Processing record 7 of set 7 | yar-sale
# City yar-sale found and added
# Processing record 8 of set 7 | ponta delgada
# City ponta delgada found and added
# Processing record 9 of set 7 | san ignacio
# City san ignacio found and added
# Processing record 10 of set 7 | egvekinot
# City egvekinot found and added
# Processing record 11 of set 7 | caucaia
# City caucaia found and added
# Processing record 12 of set 7 | hasaki
# City hasaki found and added
# Processing record 13 of set 7 | peniche
# City peniche found and added
# Processing record 14 of set 7 | labutta
# City labutta not found.  Skipping...
# Processing record 15 of set 7 | pahrump
# City pahrump found and added
# Processing record 16 of set 7 | kaardi
# City kaardi not found.  Skipping...
# Processing record 17 of set 7 | cam pha
# City cam pha not found.  Skipping...
# Processing record 18 of set 7 | salalah
# City salalah found and added
# Processing record 19 of set 7 | floro
# City floro found and added
# Processing record 20 of set 7 | sorvag
# City sorvag not found.  Skipping...
# Processing record 21 of set 7 | moba
# City moba found and added
# Processing record 22 of set 7 | pareora
# City pareora found and added
# Processing record 23 of set 7 | manta
# City manta found and added
# Processing record 24 of set 7 | san lorenzo
# City san lorenzo found and added
# Processing record 25 of set 7 | ajaccio
# City ajaccio found and added
# Processing record 26 of set 7 | fairbanks
# City fairbanks found and added
# Processing record 27 of set 7 | macau
# City macau found and added
# Processing record 28 of set 7 | luang prabang
# City luang prabang found and added
# Processing record 29 of set 7 | marcona
# City marcona not found.  Skipping...
# Processing record 30 of set 7 | falealupo
# City falealupo not found.  Skipping...
# Processing record 31 of set 7 | sulangan
# City sulangan found and added
# Processing record 32 of set 7 | babanusah
# City babanusah not found.  Skipping...
# Processing record 33 of set 7 | saskylakh
# City saskylakh found and added
# Processing record 34 of set 7 | flinders
# City flinders found and added
# Processing record 35 of set 7 | bodden town
# City bodden town found and added
# Processing record 36 of set 7 | masuda
# City masuda found and added
# Processing record 37 of set 7 | conceicao do araguaia
# City conceicao do araguaia found and added
# Processing record 38 of set 7 | tire
# City tire found and added
# Processing record 39 of set 7 | kirakira
# City kirakira found and added
# Processing record 40 of set 7 | ternate
# City ternate found and added
# Processing record 41 of set 7 | muhos
# City muhos found and added
# Processing record 42 of set 7 | mwinilunga
# City mwinilunga found and added
# Processing record 43 of set 7 | katsuura
# City katsuura found and added
# Processing record 44 of set 7 | shchelyayur
# City shchelyayur not found.  Skipping...
# Processing record 45 of set 7 | havoysund
# City havoysund found and added
# Processing record 46 of set 7 | baykit
# City baykit found and added
# Processing record 47 of set 7 | noshiro
# City noshiro found and added
# Processing record 48 of set 7 | san patricio
# City san patricio found and added
# Processing record 49 of set 7 | beira
# City beira found and added
# Processing record 0 of set 8 | portland
# City portland found and added
# Processing record 1 of set 8 | deputatskiy
# City deputatskiy found and added
# Processing record 2 of set 8 | karratha
# City karratha found and added
# Processing record 3 of set 8 | reyes
# City reyes found and added
# Processing record 4 of set 8 | ituni
# City ituni not found.  Skipping...
# Processing record 5 of set 8 | shinpokh
# City shinpokh found and added
# Processing record 6 of set 8 | ikalamavony
# City ikalamavony found and added
# Processing record 7 of set 8 | sisimiut
# City sisimiut found and added
# Processing record 8 of set 8 | yamada
# City yamada found and added
# Processing record 9 of set 8 | mutoko
# City mutoko found and added
# Processing record 10 of set 8 | joshimath
# City joshimath found and added
# Processing record 11 of set 8 | labuhan
# City labuhan found and added
# Processing record 12 of set 8 | nemuro
# City nemuro found and added
# Processing record 13 of set 8 | surt
# City surt found and added
# Processing record 14 of set 8 | camana
# City camana not found.  Skipping...
# Processing record 15 of set 8 | lethem
# City lethem found and added
# Processing record 16 of set 8 | waterford
# City waterford found and added
# Processing record 17 of set 8 | florianopolis
# City florianopolis found and added
# Processing record 18 of set 8 | karakendzha
# City karakendzha not found.  Skipping...
# Processing record 19 of set 8 | geraldton
# City geraldton found and added
# Processing record 20 of set 8 | sola
# City sola found and added
# Processing record 21 of set 8 | vaitape
# City vaitape found and added
# Processing record 22 of set 8 | mareeba
# City mareeba found and added
# Processing record 23 of set 8 | nouakchott
# City nouakchott found and added
# Processing record 24 of set 8 | piacabucu
# City piacabucu found and added
# Processing record 25 of set 8 | hobyo
# City hobyo found and added
# Processing record 26 of set 8 | paamiut
# City paamiut found and added
# Processing record 27 of set 8 | atherton
# City atherton found and added
# Processing record 28 of set 8 | belmonte
# City belmonte found and added
# Processing record 29 of set 8 | chilliwack
# City chilliwack found and added
# Processing record 30 of set 8 | oktyabrskoye
# City oktyabrskoye found and added
# Processing record 31 of set 8 | wattegama
# City wattegama found and added
# Processing record 32 of set 8 | qafsah
# City qafsah not found.  Skipping...
# Processing record 33 of set 8 | the valley
# City the valley found and added
# Processing record 34 of set 8 | huarmey
# City huarmey found and added
# Processing record 35 of set 8 | jinzhou
# City jinzhou found and added
# Processing record 36 of set 8 | foshan
# City foshan found and added
# Processing record 37 of set 8 | sallama
# City sallama found and added
# Processing record 38 of set 8 | kumluca
# City kumluca found and added
# Processing record 39 of set 8 | turukhansk
# City turukhansk found and added
# Processing record 40 of set 8 | ludvika
# City ludvika found and added
# Processing record 41 of set 8 | skjervoy
# City skjervoy found and added
# Processing record 42 of set 8 | come
# City come found and added
# Processing record 43 of set 8 | mrirt
# City mrirt not found.  Skipping...
# Processing record 44 of set 8 | namatanai
# City namatanai found and added
# Processing record 45 of set 8 | luanda
# City luanda found and added
# Processing record 46 of set 8 | angoram
# City angoram found and added
# Processing record 47 of set 8 | aberdeen
# City aberdeen found and added
# Processing record 48 of set 8 | san cristobal
# City san cristobal found and added
# Processing record 49 of set 8 | golubitskaya
# City golubitskaya found and added
# Processing record 0 of set 9 | svetlyy
# City svetlyy not found.  Skipping...
# Processing record 1 of set 9 | artesia
# City artesia found and added
# Processing record 2 of set 9 | igarka
# City igarka found and added
# Processing record 3 of set 9 | hosakote
# City hosakote found and added
# Processing record 4 of set 9 | mala
# City mala found and added
# Processing record 5 of set 9 | tura
# City tura found and added
# Processing record 6 of set 9 | kollumerland
# City kollumerland not found.  Skipping...
# Processing record 7 of set 9 | lolua
# City lolua not found.  Skipping...
# Processing record 8 of set 9 | alexandria
# City alexandria found and added
# Processing record 9 of set 9 | simao
# City simao found and added
# Processing record 10 of set 9 | kurumkan
# City kurumkan found and added
# Processing record 11 of set 9 | carndonagh
# City carndonagh found and added
# Processing record 12 of set 9 | pilao arcado
# City pilao arcado not found.  Skipping...
# Processing record 13 of set 9 | felipe carrillo puerto
# City felipe carrillo puerto found and added
# Processing record 14 of set 9 | abu road
# City abu road found and added
# Processing record 15 of set 9 | solhan
# City solhan found and added
# Processing record 16 of set 9 | pali
# City pali found and added
# Processing record 17 of set 9 | ust-barguzin
# City ust-barguzin found and added
# Processing record 18 of set 9 | ibotirama
# City ibotirama found and added
# Processing record 19 of set 9 | awjilah
# City awjilah found and added
# Processing record 20 of set 9 | horta
# City horta found and added
# Processing record 21 of set 9 | mildura
# City mildura found and added
# Processing record 22 of set 9 | jolalpan
# City jolalpan found and added
# Processing record 23 of set 9 | vangaindrano
# City vangaindrano found and added
# Processing record 24 of set 9 | korla
# City korla not found.  Skipping...
# Processing record 25 of set 9 | odate
# City odate found and added
# Processing record 26 of set 9 | lagoa
# City lagoa found and added
# Processing record 27 of set 9 | bangonay
# City bangonay found and added
# Processing record 28 of set 9 | beidao
# City beidao found and added
# Processing record 29 of set 9 | koumac
# City koumac found and added
# Processing record 30 of set 9 | toamasina
# City toamasina found and added
# Processing record 31 of set 9 | velingara
# City velingara found and added
# Processing record 32 of set 9 | petrozavodsk
# City petrozavodsk found and added
# Processing record 33 of set 9 | yomitan
# City yomitan not found.  Skipping...
# Processing record 34 of set 9 | nome
# City nome found and added
# Processing record 35 of set 9 | naze
# City naze found and added
# Processing record 36 of set 9 | ulladulla
# City ulladulla found and added
# Processing record 37 of set 9 | erenhot
# City erenhot found and added
# Processing record 38 of set 9 | morgan city
# City morgan city found and added
# Processing record 39 of set 9 | atar
# City atar found and added
# Processing record 40 of set 9 | hofn
# City hofn found and added
# Processing record 41 of set 9 | hami
# City hami found and added
# Processing record 42 of set 9 | nueve de julio
# City nueve de julio found and added
# Processing record 43 of set 9 | ketchikan
# City ketchikan found and added
# Processing record 44 of set 9 | villanueva
# City villanueva found and added
# Processing record 45 of set 9 | garza garcia
# City garza garcia found and added
# Processing record 46 of set 9 | bundaberg
# City bundaberg found and added
# Processing record 47 of set 9 | mezhdurechensk
# City mezhdurechensk found and added
# Processing record 48 of set 9 | miranorte
# City miranorte not found.  Skipping...
# Processing record 49 of set 9 | alice town
# City alice town found and added
# Processing record 0 of set 10 | genoa
# City genoa found and added
# Processing record 1 of set 10 | umm kaddadah
# City umm kaddadah found and added
# Processing record 2 of set 10 | kruisfontein
# City kruisfontein found and added
# Processing record 3 of set 10 | broome
# City broome found and added
# Processing record 4 of set 10 | rio gallegos
# City rio gallegos found and added
# Processing record 5 of set 10 | jiddah
# City jiddah not found.  Skipping...
# Processing record 6 of set 10 | pitimbu
# City pitimbu found and added
# Processing record 7 of set 10 | zeya
# City zeya found and added
# Processing record 8 of set 10 | asau
# City asau not found.  Skipping...
# Processing record 9 of set 10 | makakilo city
# City makakilo city found and added
# Processing record 10 of set 10 | digapahandi
# City digapahandi found and added
# Processing record 11 of set 10 | talnakh
# City talnakh found and added
# Processing record 12 of set 10 | cayenne
# City cayenne found and added
# Processing record 13 of set 10 | waitati
# City waitati found and added
# Processing record 14 of set 10 | ereymentau
# City ereymentau found and added
# Processing record 15 of set 10 | luganville
# City luganville found and added
# Processing record 16 of set 10 | barentsburg
# City barentsburg not found.  Skipping...
# Processing record 17 of set 10 | souillac
# City souillac found and added
# Processing record 18 of set 10 | pestovo
# City pestovo found and added
# Processing record 19 of set 10 | suzu
# City suzu not found.  Skipping...
# Processing record 20 of set 10 | samalaeulu
# City samalaeulu not found.  Skipping...
# Processing record 21 of set 10 | barsovo
# City barsovo found and added
# Processing record 22 of set 10 | kalmunai
# City kalmunai found and added
# Processing record 23 of set 10 | serenje
# City serenje found and added
# Processing record 24 of set 10 | norman wells
# City norman wells found and added
# Processing record 25 of set 10 | solnechnyy
# City solnechnyy found and added
# Processing record 26 of set 10 | guerrero negro
# City guerrero negro found and added
# Processing record 27 of set 10 | smidovich
# City smidovich found and added
# Processing record 28 of set 10 | vardo
# City vardo found and added
# Processing record 29 of set 10 | ust-tsilma
# City ust-tsilma found and added
# Processing record 30 of set 10 | komsomolskiy
# City komsomolskiy found and added
# Processing record 31 of set 10 | krasnyy chikoy
# City krasnyy chikoy found and added
# Processing record 32 of set 10 | muros
# City muros found and added
# Processing record 33 of set 10 | kahului
# City kahului found and added
# Processing record 34 of set 10 | shiyan
# City shiyan found and added
# Processing record 35 of set 10 | santa vitoria do palmar
# City santa vitoria do palmar found and added
# Processing record 36 of set 10 | torremolinos
# City torremolinos found and added
# Processing record 37 of set 10 | lorengau
# City lorengau found and added
# Processing record 38 of set 10 | demirci
# City demirci found and added
# Processing record 39 of set 10 | antalaha
# City antalaha found and added
# Processing record 40 of set 10 | orbetello
# City orbetello found and added
# Processing record 41 of set 10 | lucea
# City lucea found and added
# Processing record 42 of set 10 | saint anthony
# City saint anthony found and added
# Processing record 43 of set 10 | shiraz
# City shiraz found and added
# Processing record 44 of set 10 | cockburn town
# City cockburn town found and added
# Processing record 45 of set 10 | santa cruz de la palma
# City santa cruz de la palma found and added
# Processing record 46 of set 10 | abu kamal
# City abu kamal found and added
# Processing record 47 of set 10 | chifeng
# City chifeng found and added
# Processing record 48 of set 10 | alvik
# City alvik found and added
# Processing record 49 of set 10 | kyren
# City kyren found and added
# Processing record 0 of set 11 | plettenberg bay
# City plettenberg bay found and added
# Processing record 1 of set 11 | strezhevoy
# City strezhevoy found and added
# Processing record 2 of set 11 | amahai
# City amahai found and added
# Processing record 3 of set 11 | calama
# City calama found and added
# Processing record 4 of set 11 | rungata
# City rungata not found.  Skipping...
# Processing record 5 of set 11 | ust-omchug
# City ust-omchug found and added
# Processing record 6 of set 11 | afmadu
# City afmadu not found.  Skipping...
# Processing record 7 of set 11 | shenjiamen
# City shenjiamen found and added
# Processing record 8 of set 11 | natitingou
# City natitingou found and added
# Processing record 9 of set 11 | kayes
# City kayes found and added
# Processing record 10 of set 11 | los llanos de aridane
# City los llanos de aridane found and added
# Processing record 11 of set 11 | moindou
# City moindou found and added
# Processing record 12 of set 11 | zalantun
# City zalantun found and added
# Processing record 13 of set 11 | kibaya
# City kibaya found and added
# Processing record 14 of set 11 | biscarrosse
# City biscarrosse found and added
# Processing record 15 of set 11 | malwan
# City malwan not found.  Skipping...
# Processing record 16 of set 11 | ambo
# City ambo found and added
# Processing record 17 of set 11 | tsabong
# City tsabong found and added
# Processing record 18 of set 11 | salo
# City salo found and added
# Processing record 19 of set 11 | beeville
# City beeville found and added
# Processing record 20 of set 11 | songea
# City songea found and added
# Processing record 21 of set 11 | librazhd
# City librazhd found and added
# Processing record 22 of set 11 | shkotovo-26
# City shkotovo-26 not found.  Skipping...
# Processing record 23 of set 11 | hajiganj
# City hajiganj found and added
# Processing record 24 of set 11 | auki
# City auki found and added
# Processing record 25 of set 11 | susaki
# City susaki found and added
# Processing record 26 of set 11 | patea
# City patea found and added
# Processing record 27 of set 11 | santa marta
# City santa marta found and added
# Processing record 28 of set 11 | black forest
# City black forest found and added
# Processing record 29 of set 11 | aflu
# City aflu not found.  Skipping...
# Processing record 30 of set 11 | delray beach
# City delray beach found and added
# Processing record 31 of set 11 | sur
# City sur found and added
# Processing record 32 of set 11 | lavrentiya
# City lavrentiya found and added
# Processing record 33 of set 11 | wilmington
# City wilmington found and added
# Processing record 34 of set 11 | shitanjing
# City shitanjing found and added
# Processing record 35 of set 11 | touba
# City touba found and added
# Processing record 36 of set 11 | yaring
# City yaring found and added
# Processing record 37 of set 11 | scottsbluff
# City scottsbluff found and added
# Processing record 38 of set 11 | ancud
# City ancud found and added
# Processing record 39 of set 11 | vereya
# City vereya found and added
# Processing record 40 of set 11 | davila
# City davila found and added
# Processing record 41 of set 11 | yakeshi
# City yakeshi found and added
# Processing record 42 of set 11 | samarai
# City samarai found and added
# Processing record 43 of set 11 | half moon bay
# City half moon bay found and added
# Processing record 44 of set 11 | vilcun
# City vilcun found and added
# Processing record 45 of set 11 | kieta
# City kieta found and added
# Processing record 46 of set 11 | sungaipenuh
# City sungaipenuh found and added
# Processing record 47 of set 11 | wainwright
# City wainwright found and added
# Processing record 48 of set 11 | buala
# City buala found and added
# Processing record 49 of set 11 | manali
# City manali found and added
# Processing record 0 of set 12 | jeffersonville
# City jeffersonville found and added
# Processing record 1 of set 12 | viedma
# City viedma found and added
# Processing record 2 of set 12 | moberly
# City moberly found and added
# Processing record 3 of set 12 | maebaru
# City maebaru found and added
# Processing record 4 of set 12 | formoso do araguaia
# City formoso do araguaia not found.  Skipping...
# Processing record 5 of set 12 | saint-augustin
# City saint-augustin found and added
# Processing record 6 of set 12 | wanaka
# City wanaka found and added
# Processing record 7 of set 12 | cairns
# City cairns found and added
# Processing record 8 of set 12 | ushibuka
# City ushibuka found and added
# Processing record 9 of set 12 | san lawrenz
# City san lawrenz found and added
# Processing record 10 of set 12 | paradwip
# City paradwip not found.  Skipping...
# Processing record 11 of set 12 | graaff-reinet
# City graaff-reinet found and added
# Processing record 12 of set 12 | innsbruck
# City innsbruck found and added
# Processing record 13 of set 12 | yasothon
# City yasothon found and added
# Processing record 14 of set 12 | evensk
# City evensk found and added
# Processing record 15 of set 12 | manokwari
# City manokwari found and added
# Processing record 16 of set 12 | rusape
# City rusape found and added
# Processing record 17 of set 12 | fairview
# City fairview found and added
# Processing record 18 of set 12 | khandagayty
# City khandagayty found and added
# Processing record 19 of set 12 | warqla
# City warqla not found.  Skipping...
# Processing record 20 of set 12 | jinchengjiang
# City jinchengjiang not found.  Skipping...
# Processing record 21 of set 12 | lithakia
# City lithakia found and added
# Processing record 22 of set 12 | hambantota
# City hambantota found and added
# Processing record 23 of set 12 | sao domingos
# City sao domingos found and added
# Processing record 24 of set 12 | kasamwa
# City kasamwa found and added
# Processing record 25 of set 12 | beringovskiy
# City beringovskiy found and added
# Processing record 26 of set 12 | sao sebastiao
# City sao sebastiao found and added
# Processing record 27 of set 12 | freeport
# City freeport found and added
# Processing record 28 of set 12 | jalalabad
# City jalalabad found and added
# Processing record 29 of set 12 | hirara
# City hirara found and added
# Processing record 30 of set 12 | saint pete beach
# City saint pete beach found and added
# Processing record 31 of set 12 | saleaula
# City saleaula not found.  Skipping...
# Processing record 32 of set 12 | aksarka
# City aksarka found and added
# Processing record 33 of set 12 | te anau
# City te anau found and added
# Processing record 34 of set 12 | quatre cocos
# City quatre cocos found and added
# Processing record 35 of set 12 | rabo de peixe
# City rabo de peixe found and added
# Processing record 36 of set 12 | kiama
# City kiama found and added
# Processing record 37 of set 12 | grand bank
# City grand bank found and added
# Processing record 38 of set 12 | havre-saint-pierre
# City havre-saint-pierre found and added
# Processing record 39 of set 12 | srivardhan
# City srivardhan found and added
# Processing record 40 of set 12 | mackay
# City mackay found and added
# Processing record 41 of set 12 | orlik
# City orlik found and added
# Processing record 42 of set 12 | clyde river
# City clyde river found and added
# Processing record 43 of set 12 | zhanjiang
# City zhanjiang found and added
# Processing record 44 of set 12 | bathsheba
# City bathsheba found and added
# Processing record 45 of set 12 | bosaso
# City bosaso found and added
# Processing record 46 of set 12 | diofior
# City diofior found and added
# Processing record 47 of set 12 | isangel
# City isangel found and added
# Processing record 48 of set 12 | balimo
# City balimo not found.  Skipping...
# Processing record 49 of set 12 | vilhena
# City vilhena found and added
# Processing record 0 of set 13 | balkhash
# City balkhash found and added
# Processing record 1 of set 13 | ganzhou
# City ganzhou found and added
# Processing record 2 of set 13 | mina
# City mina found and added
# Processing record 3 of set 13 | treinta y tres
# City treinta y tres found and added
# Processing record 4 of set 13 | vanimo
# City vanimo found and added
# Processing record 5 of set 13 | maldonado
# City maldonado found and added
# Processing record 6 of set 13 | vammala
# City vammala found and added
# Processing record 7 of set 13 | golyshmanovo
# City golyshmanovo found and added
# Processing record 8 of set 13 | jijiga
# City jijiga found and added
# Processing record 9 of set 13 | kathu
# City kathu found and added
# Processing record 10 of set 13 | juan lacaze
# City juan lacaze found and added
# Processing record 11 of set 13 | devonport
# City devonport found and added
# Processing record 12 of set 13 | clinton
# City clinton found and added
# Processing record 13 of set 13 | tostamaa
# City tostamaa not found.  Skipping...
# Processing record 14 of set 13 | miri
# City miri found and added
# Processing record 15 of set 13 | karamea
# City karamea not found.  Skipping...
# Processing record 16 of set 13 | ban nahin
# City ban nahin found and added
# Processing record 17 of set 13 | comodoro rivadavia
# City comodoro rivadavia found and added
# Processing record 18 of set 13 | kedougou
# City kedougou found and added
# Processing record 19 of set 13 | chany
# City chany found and added
# Processing record 20 of set 13 | caruray
# City caruray found and added
# Processing record 21 of set 13 | sanmenxia
# City sanmenxia found and added
# Processing record 22 of set 13 | tulagi
# City tulagi not found.  Skipping...
# Processing record 23 of set 13 | fort saint john
# City fort saint john not found.  Skipping...
# Processing record 24 of set 13 | mastic beach
# City mastic beach found and added
# Processing record 25 of set 13 | asfi
# City asfi not found.  Skipping...
# Processing record 26 of set 13 | kutum
# City kutum found and added
# ===============
# data retrieval completed
# ===============

# %%
# city_url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5dd3fc1fa7926a34bfced07902a58ea3&q=datong'

# city_weather=rq.get(city_url).json()
# city_data.append({ 
#     "City": city,
#     "Lat": city_weather["coord"]["lat"],
#     "Lon": city_weather["coord"]["lon"],
#     "Max Temp": city_weather["main"]["temp_max"],
#     "Humidity": city_weather["main"]["humidity"],
#     "High Winds": city_weather["wind"]["speed"],
#     "Country": city_weather["sys"]["country"],
#     "Date": city_weather["dt"],
#     "Cloudiness": city_weather["cloudiness"]

# })
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-b27099a349ed> in <module>
#      11     "Country": city_weather["sys"]["country"],
#      12     "Date": city_weather["dt"],
# ---> 13     "Cloudiness": city_weather["cloudiness"]
#      14
#      15 })
#
# KeyError: 'cloudiness'

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.to_csv(output_data_file, index_label="City_ID")
lat = city_data_df.Lat
max_temps = city_data_df["Max Temp"]
humidity = city_data_df.Humidity
#cloudiness = city_data_df.Cloudiness
wind_speed = city_data_df["High Winds"]
city_data_df.head()
# Out:
#            City    Lat     Lon  Max Temp  Humidity  High Winds Country  \
# 0         pevek  69.70  170.27    -11.04        99        6.26      RU
# 1      chumikan  54.72  135.31    -17.39        75       15.21      RU
# 2         mezen  65.85   44.24     18.66        96        6.11      RU
# 3  puerto ayora  -0.74  -90.35     78.80        65        4.70      EC
# 4       rikitea -23.12 -134.97     77.43        83       10.56      PF
#
#          Date
# 0  1576710924
# 1  1576711172
# 2  1576711172
# 3  1576710953
# 4  1576710954

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lat,max_temps, edgecolor="black", linewidths=1, alpha=0.8, label="Cities")
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("output_data/Fig1.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-26363e2c641a> in <module>
#       4 plt.xlabel("Latitude")
#       5 plt.grid(True)
# ----> 6 plt.savefig("output_data/Fig1.png")
#       7 plt.show()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
# --> 530                     cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     531                 _png.write_png(renderer._renderer, fh,
#     532                                self.figure.dpi, metadata=metadata)
#
# /opt/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     445 def open_file_cm(path_or_file, mode="r", encoding=None):
#     446     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 447     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     448     if opened:
#     449         with fh:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     430             fh = bz2.BZ2File(fname, flag)
#     431         else:
# --> 432             fh = open(fname, flag, encoding=encoding)
#     433         opened = True
#     434     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/Fig1.png'

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat,humidity, edgecolor="black", linewidths=1, alpha=0.8, label="Cities")
plt.title("City Latitude vs. humidity (%s)" % time.strftime("%x"))
plt.ylabel("humidity (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("output_data/Fig1.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-15d29b7bbf53> in <module>
# ----> 1 plt.scatter(lat,humidity, edgecolor="black", linewidths=1, alpha=0.8, label="Cities")
#       2 plt.title("City Latitude vs. humidity (%s)" % time.strftime("%x"))
#       3 plt.ylabel("humidity (F)")
#       4 plt.xlabel("Latitude")
#       5 plt.grid(True)
#
# NameError: name 'lat' is not defined

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat,Cloudiness, edgecolor="black", linewidths=1, alpha=0.8, label="Cities")
plt.title("City Latitude vs. Cloudiness " % time.strftime("%x"))
plt.ylabel("Cloudiness (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("output_data/Fig1.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-ab03714e6f29> in <module>
# ----> 1 plt.scatter(lat,Cloudiness, edgecolor="black", linewidths=1, alpha=0.8, label="Cities")
#       2 plt.title("City Latitude vs. Cloudiness " % time.strftime("%x"))
#       3 plt.ylabel("Cloudiness (F)")
#       4 plt.xlabel("Latitude")
#       5 plt.grid(True)
#
# NameError: name 'lat' is not defined

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat,High Winds, edgecolor="black", linewidths=1, alpha=0.8, label="Cities")
plt.title("City Latitude vs. High Winds" % time.strftime("%x"))
plt.ylabel("High Winds (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("output_data/Fig1.png")
plt.show()
# Out:
#   File "<ipython-input-58-07b7356daefe>", line 1
#     plt.scatter(lat,High Winds, edgecolor="black", linewidths=1, alpha=0.8, label="Cities")
#                              ^
# SyntaxError: invalid syntax
