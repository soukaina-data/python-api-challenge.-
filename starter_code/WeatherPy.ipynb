# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests as rq
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
import sys

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

city_data=[]  
recor_count = 1
set_count= 1

print("Begining Data Retrieval")
print ("----------------")

for i, city in enumerate(cities):
    if (i%50==0 and i>=50):
        set_count+=1
        recor_count=0
    print(f"Processing record {recor_count} of set {set_count} | {city}")
    recor_count+=1
    city_url=url+"&q="+city
    #print(city_url)
    
    try:
        city_weather=rq.get(city_url).json()
        city_data.append({ 
            "City": city,
            "Lat": city_weather["coord"]["lat"],
            "Lon": city_weather["coord"]["lon"],
            "Max Temp": city_weather["main"]["temp_max"],
            "Humidity": city_weather["main"]["humidity"],
            "Cloudiness": city_weather["clouds"]["all"],
            "High Winds": city_weather["wind"]["speed"],
            "Country": city_weather["sys"]["country"],
            "Date": city_weather["dt"],
            

        })
        print(f"City {city} found and added")
    except:
        sys.exc_info()[0]
        print(f"City {city} not found.  Skipping...")
        pass
                 
print("===============")
print("data retrieval completed")
print ("===============")
# Out:
# Begining Data Retrieval
# ----------------
# Processing record 1 of set 1 | faanui
# City faanui found and added
# Processing record 2 of set 1 | taolanaro
# City taolanaro not found.  Skipping...
# Processing record 3 of set 1 | kodinsk
# City kodinsk found and added
# Processing record 4 of set 1 | castro
# City castro found and added
# Processing record 5 of set 1 | oktyabrskiy
# City oktyabrskiy found and added
# Processing record 6 of set 1 | busselton
# City busselton found and added
# Processing record 7 of set 1 | laguna
# City laguna found and added
# Processing record 8 of set 1 | ushuaia
# City ushuaia found and added
# Processing record 9 of set 1 | esperance
# City esperance found and added
# Processing record 10 of set 1 | beloha
# City beloha found and added
# Processing record 11 of set 1 | bathsheba
# City bathsheba found and added
# Processing record 12 of set 1 | sisophon
# City sisophon found and added
# Processing record 13 of set 1 | illoqqortoormiut
# City illoqqortoormiut not found.  Skipping...
# Processing record 14 of set 1 | wajima
# City wajima found and added
# Processing record 15 of set 1 | umzimvubu
# City umzimvubu not found.  Skipping...
# Processing record 16 of set 1 | pundaguitan
# City pundaguitan found and added
# Processing record 17 of set 1 | norman wells
# City norman wells found and added
# Processing record 18 of set 1 | avarua
# City avarua found and added
# Processing record 19 of set 1 | aflu
# City aflu not found.  Skipping...
# Processing record 20 of set 1 | qaanaaq
# City qaanaaq found and added
# Processing record 21 of set 1 | cidreira
# City cidreira found and added
# Processing record 22 of set 1 | rafai
# City rafai found and added
# Processing record 23 of set 1 | sumbawanga
# City sumbawanga found and added
# Processing record 24 of set 1 | pevek
# City pevek found and added
# Processing record 25 of set 1 | kapaa
# City kapaa found and added
# Processing record 26 of set 1 | bluff
# City bluff found and added
# Processing record 27 of set 1 | saint george
# City saint george found and added
# Processing record 28 of set 1 | jamestown
# City jamestown found and added
# Processing record 29 of set 1 | venice
# City venice found and added
# Processing record 30 of set 1 | yulara
# City yulara found and added
# Processing record 31 of set 1 | sept-iles
# City sept-iles found and added
# Processing record 32 of set 1 | brae
# City brae found and added
# Processing record 33 of set 1 | villa rica
# City villa rica found and added
# Processing record 34 of set 1 | ucluelet
# City ucluelet found and added
# Processing record 35 of set 1 | yellowknife
# City yellowknife found and added
# Processing record 36 of set 1 | airai
# City airai found and added
# Processing record 37 of set 1 | beringovskiy
# City beringovskiy found and added
# Processing record 38 of set 1 | vaini
# City vaini found and added
# Processing record 39 of set 1 | te anau
# City te anau found and added
# Processing record 40 of set 1 | albany
# City albany found and added
# Processing record 41 of set 1 | poltavka
# City poltavka found and added
# Processing record 42 of set 1 | rikitea
# City rikitea found and added
# Processing record 43 of set 1 | chernyshevskiy
# City chernyshevskiy found and added
# Processing record 44 of set 1 | hermanus
# City hermanus found and added
# Processing record 45 of set 1 | ust-kamchatsk
# City ust-kamchatsk not found.  Skipping...
# Processing record 46 of set 1 | poli
# City poli found and added
# Processing record 47 of set 1 | haverfordwest
# City haverfordwest found and added
# Processing record 48 of set 1 | mankono
# City mankono found and added
# Processing record 49 of set 1 | san vicente
# City san vicente found and added
# Processing record 50 of set 1 | mataura
# City mataura found and added
# Processing record 0 of set 2 | grand river south east
# City grand river south east not found.  Skipping...
# Processing record 1 of set 2 | tsihombe
# City tsihombe not found.  Skipping...
# Processing record 2 of set 2 | marcona
# City marcona not found.  Skipping...
# Processing record 3 of set 2 | sabang
# City sabang found and added
# Processing record 4 of set 2 | hilo
# City hilo found and added
# Processing record 5 of set 2 | tuktoyaktuk
# City tuktoyaktuk found and added
# Processing record 6 of set 2 | chistogorskiy
# City chistogorskiy found and added
# Processing record 7 of set 2 | nyurba
# City nyurba found and added
# Processing record 8 of set 2 | saint-philippe
# City saint-philippe found and added
# Processing record 9 of set 2 | thinadhoo
# City thinadhoo found and added
# Processing record 10 of set 2 | cape town
# City cape town found and added
# Processing record 11 of set 2 | tual
# City tual found and added
# Processing record 12 of set 2 | opuwo
# City opuwo found and added
# Processing record 13 of set 2 | fallon
# City fallon found and added
# Processing record 14 of set 2 | aykhal
# City aykhal found and added
# Processing record 15 of set 2 | antalaha
# City antalaha found and added
# Processing record 16 of set 2 | andros
# City andros found and added
# Processing record 17 of set 2 | labuhan
# City labuhan found and added
# Processing record 18 of set 2 | gull lake
# City gull lake found and added
# Processing record 19 of set 2 | deputatskiy
# City deputatskiy found and added
# Processing record 20 of set 2 | jardim
# City jardim found and added
# Processing record 21 of set 2 | butaritari
# City butaritari found and added
# Processing record 22 of set 2 | lebu
# City lebu found and added
# Processing record 23 of set 2 | hangu
# City hangu found and added
# Processing record 24 of set 2 | bethel
# City bethel found and added
# Processing record 25 of set 2 | clyde river
# City clyde river found and added
# Processing record 26 of set 2 | fortuna
# City fortuna found and added
# Processing record 27 of set 2 | kodiak
# City kodiak found and added
# Processing record 28 of set 2 | dingle
# City dingle found and added
# Processing record 29 of set 2 | oussouye
# City oussouye found and added
# Processing record 30 of set 2 | lorengau
# City lorengau found and added
# Processing record 31 of set 2 | torbay
# City torbay found and added
# Processing record 32 of set 2 | talnakh
# City talnakh found and added
# Processing record 33 of set 2 | okha
# City okha found and added
# Processing record 34 of set 2 | caravelas
# City caravelas found and added
# Processing record 35 of set 2 | cabiraoan
# City cabiraoan found and added
# Processing record 36 of set 2 | belushya guba
# City belushya guba not found.  Skipping...
# Processing record 37 of set 2 | guerrero negro
# City guerrero negro found and added
# Processing record 38 of set 2 | sao filipe
# City sao filipe found and added
# Processing record 39 of set 2 | cherskiy
# City cherskiy found and added
# Processing record 40 of set 2 | sataua
# City sataua not found.  Skipping...
# Processing record 41 of set 2 | birin
# City birin found and added
# Processing record 42 of set 2 | nirmal
# City nirmal found and added
# Processing record 43 of set 2 | egvekinot
# City egvekinot found and added
# Processing record 44 of set 2 | zhanaozen
# City zhanaozen found and added
# Processing record 45 of set 2 | tyulyachi
# City tyulyachi found and added
# Processing record 46 of set 2 | yaan
# City yaan found and added
# Processing record 47 of set 2 | hobart
# City hobart found and added
# Processing record 48 of set 2 | jiddah
# City jiddah not found.  Skipping...
# Processing record 49 of set 2 | henties bay
# City henties bay found and added
# Processing record 0 of set 3 | marsa matruh
# City marsa matruh found and added
# Processing record 1 of set 3 | omsukchan
# City omsukchan found and added
# Processing record 2 of set 3 | gigmoto
# City gigmoto found and added
# Processing record 3 of set 3 | fare
# City fare found and added
# Processing record 4 of set 3 | ponta do sol
# City ponta do sol found and added
# Processing record 5 of set 3 | gorkovskoye
# City gorkovskoye not found.  Skipping...
# Processing record 6 of set 3 | camana
# City camana found and added
# Processing record 7 of set 3 | lilongwe
# City lilongwe found and added
# Processing record 8 of set 3 | rio branco
# City rio branco found and added
# Processing record 9 of set 3 | san ramon de la nueva oran
# City san ramon de la nueva oran found and added
# Processing record 10 of set 3 | upernavik
# City upernavik found and added
# Processing record 11 of set 3 | am timan
# City am timan found and added
# Processing record 12 of set 3 | oktyabrskoye
# City oktyabrskoye found and added
# Processing record 13 of set 3 | wicklow
# City wicklow found and added
# Processing record 14 of set 3 | kaitangata
# City kaitangata found and added
# Processing record 15 of set 3 | nizhneyansk
# City nizhneyansk not found.  Skipping...
# Processing record 16 of set 3 | montepuez
# City montepuez found and added
# Processing record 17 of set 3 | port elizabeth
# City port elizabeth found and added
# Processing record 18 of set 3 | victoria
# City victoria found and added
# Processing record 19 of set 3 | attawapiskat
# City attawapiskat not found.  Skipping...
# Processing record 20 of set 3 | bengkulu
# City bengkulu found and added
# Processing record 21 of set 3 | los llanos de aridane
# City los llanos de aridane found and added
# Processing record 22 of set 3 | omboue
# City omboue found and added
# Processing record 23 of set 3 | ekuvukeni
# City ekuvukeni found and added
# Processing record 24 of set 3 | port alfred
# City port alfred found and added
# Processing record 25 of set 3 | thompson
# City thompson found and added
# Processing record 26 of set 3 | ilhabela
# City ilhabela found and added
# Processing record 27 of set 3 | new norfolk
# City new norfolk found and added
# Processing record 28 of set 3 | punta arenas
# City punta arenas found and added
# Processing record 29 of set 3 | broome
# City broome found and added
# Processing record 30 of set 3 | mangrol
# City mangrol found and added
# Processing record 31 of set 3 | kilingi-nomme
# City kilingi-nomme found and added
# Processing record 32 of set 3 | severo-kurilsk
# City severo-kurilsk found and added
# Processing record 33 of set 3 | buchanan
# City buchanan found and added
# Processing record 34 of set 3 | alice springs
# City alice springs found and added
# Processing record 35 of set 3 | puerto ayora
# City puerto ayora found and added
# Processing record 36 of set 3 | ambilobe
# City ambilobe found and added
# Processing record 37 of set 3 | amderma
# City amderma not found.  Skipping...
# Processing record 38 of set 3 | tumannyy
# City tumannyy not found.  Skipping...
# Processing record 39 of set 3 | ilulissat
# City ilulissat found and added
# Processing record 40 of set 3 | luderitz
# City luderitz found and added
# Processing record 41 of set 3 | mana
# City mana found and added
# Processing record 42 of set 3 | umm lajj
# City umm lajj found and added
# Processing record 43 of set 3 | dikson
# City dikson found and added
# Processing record 44 of set 3 | haines junction
# City haines junction found and added
# Processing record 45 of set 3 | phrai bung
# City phrai bung not found.  Skipping...
# Processing record 46 of set 3 | emba
# City emba found and added
# Processing record 47 of set 3 | kyaikkami
# City kyaikkami found and added
# Processing record 48 of set 3 | ufimskiy
# City ufimskiy found and added
# Processing record 49 of set 3 | takoradi
# City takoradi found and added
# Processing record 0 of set 4 | amapa
# City amapa found and added
# Processing record 1 of set 4 | autazes
# City autazes found and added
# Processing record 2 of set 4 | san quintin
# City san quintin found and added
# Processing record 3 of set 4 | port hedland
# City port hedland found and added
# Processing record 4 of set 4 | evensk
# City evensk found and added
# Processing record 5 of set 4 | hersbruck
# City hersbruck found and added
# Processing record 6 of set 4 | port lincoln
# City port lincoln found and added
# Processing record 7 of set 4 | sentyabrskiy
# City sentyabrskiy not found.  Skipping...
# Processing record 8 of set 4 | siria
# City siria found and added
# Processing record 9 of set 4 | chokurdakh
# City chokurdakh found and added
# Processing record 10 of set 4 | touros
# City touros found and added
# Processing record 11 of set 4 | broken hill
# City broken hill found and added
# Processing record 12 of set 4 | okhotsk
# City okhotsk found and added
# Processing record 13 of set 4 | urucara
# City urucara found and added
# Processing record 14 of set 4 | marystown
# City marystown found and added
# Processing record 15 of set 4 | ibicarai
# City ibicarai found and added
# Processing record 16 of set 4 | longyearbyen
# City longyearbyen found and added
# Processing record 17 of set 4 | sola
# City sola found and added
# Processing record 18 of set 4 | betsiamites
# City betsiamites found and added
# Processing record 19 of set 4 | zyryanka
# City zyryanka found and added
# Processing record 20 of set 4 | frutal
# City frutal found and added
# Processing record 21 of set 4 | mehamn
# City mehamn found and added
# Processing record 22 of set 4 | mfou
# City mfou found and added
# Processing record 23 of set 4 | lompoc
# City lompoc found and added
# Processing record 24 of set 4 | bubaque
# City bubaque found and added
# Processing record 25 of set 4 | vila
# City vila found and added
# Processing record 26 of set 4 | san jose
# City san jose found and added
# Processing record 27 of set 4 | troy
# City troy found and added
# Processing record 28 of set 4 | chimoio
# City chimoio found and added
# Processing record 29 of set 4 | guarapari
# City guarapari found and added
# Processing record 30 of set 4 | nikolskoye
# City nikolskoye found and added
# Processing record 31 of set 4 | ancud
# City ancud found and added
# Processing record 32 of set 4 | east london
# City east london found and added
# Processing record 33 of set 4 | callaguip
# City callaguip found and added
# Processing record 34 of set 4 | mahadday weyne
# City mahadday weyne not found.  Skipping...
# Processing record 35 of set 4 | isangel
# City isangel found and added
# Processing record 36 of set 4 | rocha
# City rocha found and added
# Processing record 37 of set 4 | palabuhanratu
# City palabuhanratu not found.  Skipping...
# Processing record 38 of set 4 | mayya
# City mayya found and added
# Processing record 39 of set 4 | satitoa
# City satitoa not found.  Skipping...
# Processing record 40 of set 4 | nizhniy kuranakh
# City nizhniy kuranakh found and added
# Processing record 41 of set 4 | scottsbluff
# City scottsbluff found and added
# Processing record 42 of set 4 | saldanha
# City saldanha found and added
# Processing record 43 of set 4 | sitka
# City sitka found and added
# Processing record 44 of set 4 | ruteng
# City ruteng found and added
# Processing record 45 of set 4 | bredasdorp
# City bredasdorp found and added
# Processing record 46 of set 4 | baykit
# City baykit found and added
# Processing record 47 of set 4 | avare
# City avare found and added
# Processing record 48 of set 4 | chifeng
# City chifeng found and added
# Processing record 49 of set 4 | baruun-urt
# City baruun-urt found and added
# Processing record 0 of set 5 | harbin
# City harbin found and added
# Processing record 1 of set 5 | atuona
# City atuona found and added
# Processing record 2 of set 5 | longyan
# City longyan found and added
# Processing record 3 of set 5 | kunming
# City kunming found and added
# Processing record 4 of set 5 | saint-georges
# City saint-georges found and added
# Processing record 5 of set 5 | cabo san lucas
# City cabo san lucas found and added
# Processing record 6 of set 5 | vanimo
# City vanimo found and added
# Processing record 7 of set 5 | nanga eboko
# City nanga eboko found and added
# Processing record 8 of set 5 | maragogi
# City maragogi found and added
# Processing record 9 of set 5 | lolua
# City lolua not found.  Skipping...
# Processing record 10 of set 5 | tucupita
# City tucupita found and added
# Processing record 11 of set 5 | shenjiamen
# City shenjiamen found and added
# Processing record 12 of set 5 | nara
# City nara found and added
# Processing record 13 of set 5 | saquarema
# City saquarema found and added
# Processing record 14 of set 5 | port augusta
# City port augusta found and added
# Processing record 15 of set 5 | thanh hoa
# City thanh hoa found and added
# Processing record 16 of set 5 | keuruu
# City keuruu found and added
# Processing record 17 of set 5 | ribeira grande
# City ribeira grande found and added
# Processing record 18 of set 5 | santa teresa
# City santa teresa found and added
# Processing record 19 of set 5 | buariki
# City buariki not found.  Skipping...
# Processing record 20 of set 5 | velika gorica
# City velika gorica found and added
# Processing record 21 of set 5 | korla
# City korla found and added
# Processing record 22 of set 5 | havoysund
# City havoysund found and added
# Processing record 23 of set 5 | porto novo
# City porto novo found and added
# Processing record 24 of set 5 | bambous virieux
# City bambous virieux found and added
# Processing record 25 of set 5 | kargat
# City kargat found and added
# Processing record 26 of set 5 | alyangula
# City alyangula found and added
# Processing record 27 of set 5 | aklavik
# City aklavik found and added
# Processing record 28 of set 5 | dunedin
# City dunedin found and added
# Processing record 29 of set 5 | como
# City como found and added
# Processing record 30 of set 5 | shaowu
# City shaowu found and added
# Processing record 31 of set 5 | qaqortoq
# City qaqortoq found and added
# Processing record 32 of set 5 | oswego
# City oswego found and added
# Processing record 33 of set 5 | makakilo city
# City makakilo city found and added
# Processing record 34 of set 5 | natchitoches
# City natchitoches found and added
# Processing record 35 of set 5 | acarau
# City acarau found and added
# Processing record 36 of set 5 | nizwa
# City nizwa found and added
# Processing record 37 of set 5 | mogadishu
# City mogadishu found and added
# Processing record 38 of set 5 | miles city
# City miles city found and added
# Processing record 39 of set 5 | slave lake
# City slave lake found and added
# Processing record 40 of set 5 | tasiilaq
# City tasiilaq found and added
# Processing record 41 of set 5 | pampa
# City pampa found and added
# Processing record 42 of set 5 | kruisfontein
# City kruisfontein found and added
# Processing record 43 of set 5 | vila franca do campo
# City vila franca do campo found and added
# Processing record 44 of set 5 | magdalena
# City magdalena found and added
# Processing record 45 of set 5 | mar del plata
# City mar del plata found and added
# Processing record 46 of set 5 | barentsburg
# City barentsburg not found.  Skipping...
# Processing record 47 of set 5 | careiro da varzea
# City careiro da varzea found and added
# Processing record 48 of set 5 | aconibe
# City aconibe found and added
# Processing record 49 of set 5 | namibe
# City namibe found and added
# Processing record 0 of set 6 | grindavik
# City grindavik found and added
# Processing record 1 of set 6 | sinnamary
# City sinnamary found and added
# Processing record 2 of set 6 | georgetown
# City georgetown found and added
# Processing record 3 of set 6 | itaueira
# City itaueira found and added
# Processing record 4 of set 6 | sohag
# City sohag found and added
# Processing record 5 of set 6 | russkaya polyana
# City russkaya polyana found and added
# Processing record 6 of set 6 | isla vista
# City isla vista found and added
# Processing record 7 of set 6 | corn island
# City corn island found and added
# Processing record 8 of set 6 | sungaipenuh
# City sungaipenuh found and added
# Processing record 9 of set 6 | mata
# City mata found and added
# Processing record 10 of set 6 | kavieng
# City kavieng found and added
# Processing record 11 of set 6 | camopi
# City camopi found and added
# Processing record 12 of set 6 | shelburne
# City shelburne found and added
# Processing record 13 of set 6 | atar
# City atar found and added
# Processing record 14 of set 6 | souillac
# City souillac found and added
# Processing record 15 of set 6 | half moon bay
# City half moon bay found and added
# Processing record 16 of set 6 | barrow
# City barrow found and added
# Processing record 17 of set 6 | kudahuvadhoo
# City kudahuvadhoo found and added
# Processing record 18 of set 6 | inderborskiy
# City inderborskiy not found.  Skipping...
# Processing record 19 of set 6 | nikki
# City nikki found and added
# Processing record 20 of set 6 | wanlaweyn
# City wanlaweyn found and added
# Processing record 21 of set 6 | port-gentil
# City port-gentil found and added
# Processing record 22 of set 6 | vaitupu
# City vaitupu not found.  Skipping...
# Processing record 23 of set 6 | coahuayana
# City coahuayana found and added
# Processing record 24 of set 6 | lafiagi
# City lafiagi found and added
# Processing record 25 of set 6 | banes
# City banes found and added
# Processing record 26 of set 6 | verkhnetulomskiy
# City verkhnetulomskiy found and added
# Processing record 27 of set 6 | ostrovnoy
# City ostrovnoy found and added
# Processing record 28 of set 6 | saint-augustin
# City saint-augustin found and added
# Processing record 29 of set 6 | noumea
# City noumea found and added
# Processing record 30 of set 6 | sobolevo
# City sobolevo found and added
# Processing record 31 of set 6 | gat
# City gat found and added
# Processing record 32 of set 6 | mys shmidta
# City mys shmidta not found.  Skipping...
# Processing record 33 of set 6 | anan
# City anan found and added
# Processing record 34 of set 6 | iqaluit
# City iqaluit found and added
# Processing record 35 of set 6 | lavrentiya
# City lavrentiya found and added
# Processing record 36 of set 6 | cheuskiny
# City cheuskiny not found.  Skipping...
# Processing record 37 of set 6 | sumter
# City sumter found and added
# Processing record 38 of set 6 | zhigansk
# City zhigansk found and added
# Processing record 39 of set 6 | ola
# City ola found and added
# Processing record 40 of set 6 | shimanovsk
# City shimanovsk found and added
# Processing record 41 of set 6 | port hardy
# City port hardy found and added
# Processing record 42 of set 6 | shadrinsk
# City shadrinsk found and added
# Processing record 43 of set 6 | alta floresta
# City alta floresta found and added
# Processing record 44 of set 6 | khatanga
# City khatanga found and added
# Processing record 45 of set 6 | nome
# City nome found and added
# Processing record 46 of set 6 | hovd
# City hovd found and added
# Processing record 47 of set 6 | sarahan
# City sarahan found and added
# Processing record 48 of set 6 | samusu
# City samusu not found.  Skipping...
# Processing record 49 of set 6 | codrington
# City codrington found and added
# Processing record 0 of set 7 | chik ballapur
# City chik ballapur found and added
# Processing record 1 of set 7 | ust-nera
# City ust-nera found and added
# Processing record 2 of set 7 | katangli
# City katangli found and added
# Processing record 3 of set 7 | hithadhoo
# City hithadhoo found and added
# Processing record 4 of set 7 | corrente
# City corrente found and added
# Processing record 5 of set 7 | high level
# City high level found and added
# Processing record 6 of set 7 | akyab
# City akyab found and added
# Processing record 7 of set 7 | northam
# City northam found and added
# Processing record 8 of set 7 | kavarskas
# City kavarskas found and added
# Processing record 9 of set 7 | lata
# City lata found and added
# Processing record 10 of set 7 | avera
# City avera found and added
# Processing record 11 of set 7 | nakama
# City nakama found and added
# Processing record 12 of set 7 | inyonga
# City inyonga found and added
# Processing record 13 of set 7 | kamenskoye
# City kamenskoye not found.  Skipping...
# Processing record 14 of set 7 | tsiroanomandidy
# City tsiroanomandidy found and added
# Processing record 15 of set 7 | algiers
# City algiers found and added
# Processing record 16 of set 7 | vila velha
# City vila velha found and added
# Processing record 17 of set 7 | savannah bight
# City savannah bight found and added
# Processing record 18 of set 7 | inta
# City inta found and added
# Processing record 19 of set 7 | chipinge
# City chipinge found and added
# Processing record 20 of set 7 | mount isa
# City mount isa found and added
# Processing record 21 of set 7 | neyshabur
# City neyshabur found and added
# Processing record 22 of set 7 | lushnje
# City lushnje found and added
# Processing record 23 of set 7 | katsuura
# City katsuura found and added
# Processing record 24 of set 7 | yerbogachen
# City yerbogachen found and added
# Processing record 25 of set 7 | coquimbo
# City coquimbo found and added
# Processing record 26 of set 7 | tiksi
# City tiksi found and added
# Processing record 27 of set 7 | dhidhdhoo
# City dhidhdhoo found and added
# Processing record 28 of set 7 | mattru
# City mattru found and added
# Processing record 29 of set 7 | comodoro rivadavia
# City comodoro rivadavia found and added
# Processing record 30 of set 7 | henderson
# City henderson found and added
# Processing record 31 of set 7 | henzada
# City henzada not found.  Skipping...
# Processing record 32 of set 7 | moerai
# City moerai found and added
# Processing record 33 of set 7 | waipawa
# City waipawa found and added
# Processing record 34 of set 7 | san cristobal
# City san cristobal found and added
# Processing record 35 of set 7 | manokwari
# City manokwari found and added
# Processing record 36 of set 7 | fort wellington
# City fort wellington found and added
# Processing record 37 of set 7 | ugoofaaru
# City ugoofaaru found and added
# Processing record 38 of set 7 | kiama
# City kiama found and added
# Processing record 39 of set 7 | west lafayette
# City west lafayette found and added
# Processing record 40 of set 7 | cheremukhovo
# City cheremukhovo found and added
# Processing record 41 of set 7 | santa fe
# City santa fe found and added
# Processing record 42 of set 7 | aqtobe
# City aqtobe found and added
# Processing record 43 of set 7 | nassau
# City nassau found and added
# Processing record 44 of set 7 | ust-maya
# City ust-maya found and added
# Processing record 45 of set 7 | olafsvik
# City olafsvik found and added
# Processing record 46 of set 7 | pombas
# City pombas found and added
# Processing record 47 of set 7 | strathmore
# City strathmore found and added
# Processing record 48 of set 7 | chuy
# City chuy found and added
# Processing record 49 of set 7 | la plata
# City la plata found and added
# Processing record 0 of set 8 | rochegda
# City rochegda found and added
# Processing record 1 of set 8 | warri
# City warri found and added
# Processing record 2 of set 8 | villa carlos paz
# City villa carlos paz found and added
# Processing record 3 of set 8 | ndjole
# City ndjole found and added
# Processing record 4 of set 8 | arraial do cabo
# City arraial do cabo found and added
# Processing record 5 of set 8 | hasaki
# City hasaki found and added
# Processing record 6 of set 8 | shellbrook
# City shellbrook found and added
# Processing record 7 of set 8 | karratha
# City karratha found and added
# Processing record 8 of set 8 | rabat
# City rabat found and added
# Processing record 9 of set 8 | carnarvon
# City carnarvon found and added
# Processing record 10 of set 8 | kieta
# City kieta found and added
# Processing record 11 of set 8 | basoko
# City basoko found and added
# Processing record 12 of set 8 | batsfjord
# City batsfjord found and added
# Processing record 13 of set 8 | flin flon
# City flin flon found and added
# Processing record 14 of set 8 | ponta delgada
# City ponta delgada found and added
# Processing record 15 of set 8 | sawtell
# City sawtell found and added
# Processing record 16 of set 8 | doka
# City doka found and added
# Processing record 17 of set 8 | takab
# City takab found and added
# Processing record 18 of set 8 | tateyama
# City tateyama found and added
# Processing record 19 of set 8 | saskylakh
# City saskylakh found and added
# Processing record 20 of set 8 | hofn
# City hofn found and added
# Processing record 21 of set 8 | jacareacanga
# City jacareacanga found and added
# Processing record 22 of set 8 | gari
# City gari found and added
# Processing record 23 of set 8 | pringsewu
# City pringsewu found and added
# Processing record 24 of set 8 | riyadh
# City riyadh found and added
# Processing record 25 of set 8 | aksarka
# City aksarka found and added
# Processing record 26 of set 8 | inuvik
# City inuvik found and added
# Processing record 27 of set 8 | cabatuan
# City cabatuan found and added
# Processing record 28 of set 8 | port blair
# City port blair found and added
# Processing record 29 of set 8 | mahebourg
# City mahebourg found and added
# Processing record 30 of set 8 | wasco
# City wasco found and added
# Processing record 31 of set 8 | vardo
# City vardo found and added
# Processing record 32 of set 8 | harper
# City harper found and added
# Processing record 33 of set 8 | mitu
# City mitu found and added
# Processing record 34 of set 8 | nishihara
# City nishihara found and added
# Processing record 35 of set 8 | mahanoro
# City mahanoro found and added
# Processing record 36 of set 8 | dalbandin
# City dalbandin found and added
# Processing record 37 of set 8 | bhadravati
# City bhadravati found and added
# Processing record 38 of set 8 | marsaxlokk
# City marsaxlokk found and added
# Processing record 39 of set 8 | ifanadiana
# City ifanadiana found and added
# Processing record 40 of set 8 | carlos chagas
# City carlos chagas found and added
# Processing record 41 of set 8 | kegayli
# City kegayli not found.  Skipping...
# Processing record 42 of set 8 | hobyo
# City hobyo found and added
# Processing record 43 of set 8 | taksimo
# City taksimo found and added
# Processing record 44 of set 8 | aden
# City aden found and added
# Processing record 45 of set 8 | lysyye gory
# City lysyye gory found and added
# Processing record 46 of set 8 | anadyr
# City anadyr found and added
# Processing record 47 of set 8 | axim
# City axim found and added
# Processing record 48 of set 8 | luwingu
# City luwingu found and added
# Processing record 49 of set 8 | liniere
# City liniere not found.  Skipping...
# Processing record 0 of set 9 | san patricio
# City san patricio found and added
# Processing record 1 of set 9 | samalaeulu
# City samalaeulu not found.  Skipping...
# Processing record 2 of set 9 | malwan
# City malwan not found.  Skipping...
# Processing record 3 of set 9 | sao joao da barra
# City sao joao da barra found and added
# Processing record 4 of set 9 | zabol
# City zabol found and added
# Processing record 5 of set 9 | bollnas
# City bollnas found and added
# Processing record 6 of set 9 | kalanguy
# City kalanguy found and added
# Processing record 7 of set 9 | deulgaon raja
# City deulgaon raja found and added
# Processing record 8 of set 9 | narsaq
# City narsaq found and added
# Processing record 9 of set 9 | aksu
# City aksu found and added
# Processing record 10 of set 9 | dudinka
# City dudinka found and added
# Processing record 11 of set 9 | takaka
# City takaka found and added
# Processing record 12 of set 9 | asayita
# City asayita not found.  Skipping...
# Processing record 13 of set 9 | redhakhol
# City redhakhol not found.  Skipping...
# Processing record 14 of set 9 | jagdalpur
# City jagdalpur found and added
# Processing record 15 of set 9 | adre
# City adre found and added
# Processing record 16 of set 9 | soma
# City soma found and added
# Processing record 17 of set 9 | nanortalik
# City nanortalik found and added
# Processing record 18 of set 9 | meulaboh
# City meulaboh found and added
# Processing record 19 of set 9 | saleaula
# City saleaula not found.  Skipping...
# Processing record 20 of set 9 | paamiut
# City paamiut found and added
# Processing record 21 of set 9 | flinders
# City flinders found and added
# Processing record 22 of set 9 | bereda
# City bereda found and added
# Processing record 23 of set 9 | uvira
# City uvira found and added
# Processing record 24 of set 9 | roald
# City roald found and added
# Processing record 25 of set 9 | yamaga
# City yamaga found and added
# Processing record 26 of set 9 | brokopondo
# City brokopondo found and added
# Processing record 27 of set 9 | kikwit
# City kikwit found and added
# Processing record 28 of set 9 | poronaysk
# City poronaysk found and added
# Processing record 29 of set 9 | adrar
# City adrar found and added
# Processing record 30 of set 9 | zolochiv
# City zolochiv found and added
# Processing record 31 of set 9 | kimparana
# City kimparana found and added
# Processing record 32 of set 9 | bud
# City bud found and added
# Processing record 33 of set 9 | ust-kuyga
# City ust-kuyga found and added
# Processing record 34 of set 9 | kavaratti
# City kavaratti found and added
# Processing record 35 of set 9 | moron
# City moron found and added
# Processing record 36 of set 9 | tapaua
# City tapaua not found.  Skipping...
# Processing record 37 of set 9 | yar-sale
# City yar-sale found and added
# Processing record 38 of set 9 | provideniya
# City provideniya found and added
# Processing record 39 of set 9 | constitucion
# City constitucion found and added
# Processing record 40 of set 9 | olavarria
# City olavarria found and added
# Processing record 41 of set 9 | bodaybo
# City bodaybo found and added
# Processing record 42 of set 9 | kushmurun
# City kushmurun found and added
# Processing record 43 of set 9 | banda aceh
# City banda aceh found and added
# Processing record 44 of set 9 | boma
# City boma found and added
# Processing record 45 of set 9 | copiapo
# City copiapo found and added
# Processing record 46 of set 9 | shakhtinsk
# City shakhtinsk found and added
# Processing record 47 of set 9 | kerouane
# City kerouane found and added
# Processing record 48 of set 9 | praya
# City praya found and added
# Processing record 49 of set 9 | huarmey
# City huarmey found and added
# Processing record 0 of set 10 | wahran
# City wahran not found.  Skipping...
# Processing record 1 of set 10 | obigarm
# City obigarm found and added
# Processing record 2 of set 10 | ulladulla
# City ulladulla found and added
# Processing record 3 of set 10 | mount gambier
# City mount gambier found and added
# Processing record 4 of set 10 | paita
# City paita found and added
# Processing record 5 of set 10 | portland
# City portland found and added
# Processing record 6 of set 10 | astaneh-ye ashrafiyeh
# City astaneh-ye ashrafiyeh found and added
# Processing record 7 of set 10 | khor
# City khor found and added
# Processing record 8 of set 10 | elizabeth city
# City elizabeth city found and added
# Processing record 9 of set 10 | matagami
# City matagami found and added
# Processing record 10 of set 10 | ostersund
# City ostersund found and added
# Processing record 11 of set 10 | edendale
# City edendale found and added
# Processing record 12 of set 10 | fairbanks
# City fairbanks found and added
# Processing record 13 of set 10 | ziarat
# City ziarat found and added
# Processing record 14 of set 10 | huangpi
# City huangpi found and added
# Processing record 15 of set 10 | kathu
# City kathu found and added
# Processing record 16 of set 10 | chirongui
# City chirongui found and added
# Processing record 17 of set 10 | catalina foothills
# City catalina foothills found and added
# Processing record 18 of set 10 | nha trang
# City nha trang found and added
# Processing record 19 of set 10 | bhan
# City bhan found and added
# Processing record 20 of set 10 | benguela
# City benguela found and added
# Processing record 21 of set 10 | pontianak
# City pontianak found and added
# Processing record 22 of set 10 | odienne
# City odienne found and added
# Processing record 23 of set 10 | vestmanna
# City vestmanna found and added
# Processing record 24 of set 10 | port-cartier
# City port-cartier found and added
# Processing record 25 of set 10 | komsomolskiy
# City komsomolskiy found and added
# Processing record 26 of set 10 | teknaf
# City teknaf found and added
# Processing record 27 of set 10 | zhuanghe
# City zhuanghe found and added
# Processing record 28 of set 10 | gasa
# City gasa found and added
# Processing record 29 of set 10 | lazaro cardenas
# City lazaro cardenas found and added
# Processing record 30 of set 10 | xining
# City xining found and added
# Processing record 31 of set 10 | garden city
# City garden city found and added
# Processing record 32 of set 10 | tadine
# City tadine found and added
# Processing record 33 of set 10 | leh
# City leh found and added
# Processing record 34 of set 10 | hualmay
# City hualmay found and added
# Processing record 35 of set 10 | jumla
# City jumla found and added
# Processing record 36 of set 10 | mansehra
# City mansehra found and added
# Processing record 37 of set 10 | itahari
# City itahari not found.  Skipping...
# Processing record 38 of set 10 | stanovoye
# City stanovoye found and added
# Processing record 39 of set 10 | general roca
# City general roca found and added
# Processing record 40 of set 10 | maldonado
# City maldonado found and added
# Processing record 41 of set 10 | spas-klepiki
# City spas-klepiki found and added
# Processing record 42 of set 10 | ballina
# City ballina found and added
# Processing record 43 of set 10 | mamallapuram
# City mamallapuram found and added
# Processing record 44 of set 10 | tubruq
# City tubruq not found.  Skipping...
# Processing record 45 of set 10 | padra
# City padra found and added
# Processing record 46 of set 10 | kloulklubed
# City kloulklubed found and added
# Processing record 47 of set 10 | ouesso
# City ouesso found and added
# Processing record 48 of set 10 | lagoa
# City lagoa found and added
# Processing record 49 of set 10 | trairi
# City trairi found and added
# Processing record 0 of set 11 | terrace
# City terrace found and added
# Processing record 1 of set 11 | asuncion nochixtlan
# City asuncion nochixtlan found and added
# Processing record 2 of set 11 | barbar
# City barbar not found.  Skipping...
# Processing record 3 of set 11 | general pico
# City general pico found and added
# Processing record 4 of set 11 | eregli
# City eregli found and added
# Processing record 5 of set 11 | naze
# City naze found and added
# Processing record 6 of set 11 | belyy yar
# City belyy yar found and added
# Processing record 7 of set 11 | clonakilty
# City clonakilty found and added
# Processing record 8 of set 11 | acapulco
# City acapulco found and added
# Processing record 9 of set 11 | katha
# City katha not found.  Skipping...
# Processing record 10 of set 11 | atambua
# City atambua found and added
# Processing record 11 of set 11 | kushima
# City kushima found and added
# Processing record 12 of set 11 | khani
# City khani found and added
# Processing record 13 of set 11 | nelson bay
# City nelson bay found and added
# Processing record 14 of set 11 | weatherford
# City weatherford found and added
# Processing record 15 of set 11 | sri aman
# City sri aman found and added
# Processing record 16 of set 11 | bambanglipuro
# City bambanglipuro found and added
# Processing record 17 of set 11 | kamenka
# City kamenka found and added
# Processing record 18 of set 11 | kinghorn
# City kinghorn found and added
# Processing record 19 of set 11 | berekum
# City berekum found and added
# Processing record 20 of set 11 | smithers
# City smithers found and added
# Processing record 21 of set 11 | seydi
# City seydi found and added
# Processing record 22 of set 11 | vestmannaeyjar
# City vestmannaeyjar found and added
# Processing record 23 of set 11 | jarocin
# City jarocin found and added
# Processing record 24 of set 11 | rawson
# City rawson found and added
# Processing record 25 of set 11 | wulanhaote
# City wulanhaote not found.  Skipping...
# Processing record 26 of set 11 | hirara
# City hirara found and added
# Processing record 27 of set 11 | phangnga
# City phangnga found and added
# Processing record 28 of set 11 | waddan
# City waddan found and added
# Processing record 29 of set 11 | nikaia
# City nikaia found and added
# Processing record 30 of set 11 | tuatapere
# City tuatapere found and added
# Processing record 31 of set 11 | tevaitoa
# City tevaitoa found and added
# Processing record 32 of set 11 | tunceli
# City tunceli found and added
# Processing record 33 of set 11 | merrill
# City merrill found and added
# Processing record 34 of set 11 | sangar
# City sangar found and added
# Processing record 35 of set 11 | matamoros
# City matamoros found and added
# Processing record 36 of set 11 | balingasay
# City balingasay found and added
# Processing record 37 of set 11 | zharkent
# City zharkent found and added
# Processing record 38 of set 11 | qesarya
# City qesarya found and added
# Processing record 39 of set 11 | yukon
# City yukon found and added
# Processing record 40 of set 11 | pleasanton
# City pleasanton found and added
# Processing record 41 of set 11 | derzhavinsk
# City derzhavinsk found and added
# Processing record 42 of set 11 | pangnirtung
# City pangnirtung found and added
# Processing record 43 of set 11 | lora del rio
# City lora del rio found and added
# Processing record 44 of set 11 | grand gaube
# City grand gaube found and added
# Processing record 45 of set 11 | shuangyang
# City shuangyang found and added
# Processing record 46 of set 11 | neuquen
# City neuquen found and added
# Processing record 47 of set 11 | skelleftea
# City skelleftea found and added
# Processing record 48 of set 11 | hidalgotitlan
# City hidalgotitlan found and added
# Processing record 49 of set 11 | husavik
# City husavik found and added
# Processing record 0 of set 12 | carora
# City carora found and added
# Processing record 1 of set 12 | alekseyevsk
# City alekseyevsk found and added
# Processing record 2 of set 12 | altona
# City altona found and added
# Processing record 3 of set 12 | kuching
# City kuching found and added
# Processing record 4 of set 12 | pacific grove
# City pacific grove found and added
# Processing record 5 of set 12 | hibbing
# City hibbing found and added
# Processing record 6 of set 12 | killybegs
# City killybegs found and added
# Processing record 7 of set 12 | louisbourg
# City louisbourg not found.  Skipping...
# Processing record 8 of set 12 | svetlaya
# City svetlaya found and added
# Processing record 9 of set 12 | arica
# City arica found and added
# Processing record 10 of set 12 | sovetskaya gavan
# City sovetskaya gavan found and added
# Processing record 11 of set 12 | dakar
# City dakar found and added
# Processing record 12 of set 12 | kualakapuas
# City kualakapuas found and added
# Processing record 13 of set 12 | maumere
# City maumere found and added
# Processing record 14 of set 12 | verkhnyaya toyma
# City verkhnyaya toyma found and added
# Processing record 15 of set 12 | ihiala
# City ihiala found and added
# Processing record 16 of set 12 | vao
# City vao found and added
# Processing record 17 of set 12 | salalah
# City salalah found and added
# Processing record 18 of set 12 | suffolk
# City suffolk found and added
# Processing record 19 of set 12 | bansi
# City bansi found and added
# Processing record 20 of set 12 | loandjili
# City loandjili found and added
# Processing record 21 of set 12 | nioro
# City nioro found and added
# Processing record 22 of set 12 | kerteh
# City kerteh not found.  Skipping...
# Processing record 23 of set 12 | damghan
# City damghan found and added
# Processing record 24 of set 12 | biak
# City biak found and added
# Processing record 25 of set 12 | yeppoon
# City yeppoon found and added
# Processing record 26 of set 12 | misratah
# City misratah found and added
# Processing record 27 of set 12 | narok
# City narok found and added
# Processing record 28 of set 12 | nhulunbuy
# City nhulunbuy found and added
# Processing record 29 of set 12 | gamba
# City gamba found and added
# Processing record 30 of set 12 | bairiki
# City bairiki found and added
# Processing record 31 of set 12 | sayyan
# City sayyan found and added
# Processing record 32 of set 12 | novo aripuana
# City novo aripuana found and added
# Processing record 33 of set 12 | livingston
# City livingston found and added
# Processing record 34 of set 12 | sibu
# City sibu found and added
# Processing record 35 of set 12 | richards bay
# City richards bay found and added
# Processing record 36 of set 12 | karaul
# City karaul not found.  Skipping...
# Processing record 37 of set 12 | kaeo
# City kaeo found and added
# Processing record 38 of set 12 | padang
# City padang found and added
# Processing record 39 of set 12 | hay river
# City hay river found and added
# Processing record 40 of set 12 | rongcheng
# City rongcheng found and added
# Processing record 41 of set 12 | beyneu
# City beyneu found and added
# Processing record 42 of set 12 | magdagachi
# City magdagachi found and added
# Processing record 43 of set 12 | tessalit
# City tessalit found and added
# Processing record 44 of set 12 | rodrigues alves
# City rodrigues alves found and added
# Processing record 45 of set 12 | kula
# City kula found and added
# Processing record 46 of set 12 | saint anthony
# City saint anthony found and added
# Processing record 47 of set 12 | bend
# City bend found and added
# Processing record 48 of set 12 | arman
# City arman found and added
# Processing record 49 of set 12 | cam pha
# City cam pha not found.  Skipping...
# Processing record 0 of set 13 | bandarbeyla
# City bandarbeyla found and added
# Processing record 1 of set 13 | meyungs
# City meyungs not found.  Skipping...
# Processing record 2 of set 13 | saint-pierre
# City saint-pierre found and added
# Processing record 3 of set 13 | telimele
# City telimele found and added
# Processing record 4 of set 13 | mooi river
# City mooi river not found.  Skipping...
# Processing record 5 of set 13 | santa vitoria do palmar
# City santa vitoria do palmar found and added
# Processing record 6 of set 13 | conakry
# City conakry found and added
# Processing record 7 of set 13 | mezdra
# City mezdra found and added
# Processing record 8 of set 13 | barra patuca
# City barra patuca found and added
# Processing record 9 of set 13 | mount vernon
# City mount vernon found and added
# Processing record 10 of set 13 | bera
# City bera found and added
# Processing record 11 of set 13 | ust-tsilma
# City ust-tsilma found and added
# Processing record 12 of set 13 | nanakuli
# City nanakuli found and added
# Processing record 13 of set 13 | castlemaine
# City castlemaine found and added
# Processing record 14 of set 13 | goderich
# City goderich found and added
# ===============
# data retrieval completed
# ===============

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.to_csv(output_data_file, index_label="City_ID")
lat = city_data_df.Lat
max_temps = city_data_df["Max Temp"]
humidity = city_data_df.Humidity
cloudiness = city_data_df.Cloudiness
wind_speed = city_data_df["High Winds"]
city_data_df.head()
# Out:
#           City    Lat     Lon  Max Temp  Humidity  Cloudiness  High Winds  \
# 0       faanui -16.48 -151.75     83.62        62          79        5.86
# 1      kodinsk  58.69   99.18     28.17        94         100       12.08
# 2       castro -24.79  -50.01     56.23        69          85        5.66
# 3  oktyabrskiy  54.48   53.47     34.66        91         100        1.88
# 4    busselton -33.65  115.33     75.38        76         100       12.77
#
#   Country        Date
# 0      PF  1585279652
# 1      RU  1585279652
# 2      BR  1585279653
# 3      RU  1585279653
# 4      AU  1585279653

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lat,max_temps, edgecolor="black", linewidths=1,alpha=0.8, label="Cities")
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("output_data/Fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat,humidity, edgecolor="black", linewidths=1, alpha=0.8, label="Cities")
plt.title("City Latitude vs. humidity (%s)" % time.strftime("%x"))
plt.ylabel("humidity (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("output_data/Fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat,cloudiness, edgecolor="black", linewidths=1, alpha=0.8, label="Cities")
plt.title("City Latitude vs. Cloudiness (%s) " % time.strftime("%x"))
plt.ylabel("Cloudiness (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("output_data/Fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat,wind_speed, edgecolor="black", linewidths=1, alpha=0.8, label="Cities")
plt.title("City Latitude vs. High Winds (%s)" % time.strftime("%x"))
plt.ylabel("High Winds (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("output_data/Fig1.png")
plt.show()
